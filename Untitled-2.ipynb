# %%
from neo4j import GraphDatabase
from langchain.chains import GraphCypherQAChain
from langchain_community.graphs import Neo4jGraph   

URI      = "neo4j+ssc://9bc6beed.databases.neo4j.io"
USER     = "9bc6beed"
PASSWORD = "UHtFuBP-iUd4gV1KEd4xGxRFO1I6trRfgxXBYwWuErg"
graph = Neo4jGraph(url=URI, username=USER, password=PASSWORD)
# Out:
# 📂 JSON 데이터를 불러오는 중입니다...
# 총 2560건의 유물 데이터가 로드되었습니다.
# 🤖 지정된 한국어 임베딩 모델을 세팅하는 중...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# 🗑️ 기존에 존재하던 'museum_relics' 컬렉션을 삭제했습니다.
# 🚀 README 요구 조건에 맞추어 임베딩 문서를 결합 및 빌드합니다...
# 빌드 진행률: 100%|██████████| 2560/2560 [03:31<00:00, 12.09it/s]
# ==================================================
# ✨ 벡터 DB 구축이 완료되었습니다!
# 📂 저장 폴더 위치: /Users/seong-yumin/boaz_project2/vector_db/chroma_museum_db
# 📊 저장 문서 수 (Target: 2560): 2560
# ==================================================

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(temperature=0,               
                 max_tokens=2048,            
                 model_name='gpt-4,0-turbo',
                )

question = 'ChatGPT가 뭐야?'

print(llm.predict(question))
