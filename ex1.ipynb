# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# api key 로딩
load_dotenv()

# open ai chat 생성
llm = ChatOpenAI()

# 질의 내용
question = "1부터5까지 더해줘"

# 실행
result = llm.invoke(question)
print(result)
# Out:
# content='1 + 2 + 3 + 4 + 5 = 15\n\n따라서, 1부터 5까지 더한 값은 15입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 20, 'total_tokens': 61, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-Dj1t221Ti62ZlWq4p0eCZEpeYZDwC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e59e1-11ba-72e0-9d39-acf4fd474648-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 20, 'output_tokens': 41, 'total_tokens': 61, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from dotenv import load_dotenv
from langchain_classic.chains import LLMChain
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI

load_dotenv()

llm = ChatOpenAI()

# 질의내용
template = "{language}로 1부터 10까지 출력하는 함수 만들어줘"

prompt = PromptTemplate.from_template(template=template)

chain = LLMChain(prompt=prompt, llm=llm)
result = chain.invoke({"language": "Java"})
print(result)
# Out:
# /var/folders/9w/b5vjp6cx24152_6bnjxdtkk40000gn/T/ipykernel_17747/3851789606.py:15: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 2.0.0. Use `RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(prompt=prompt, llm=llm)
# {'language': 'Java', 'text': '```java\npublic class Main {\n    public static void main(String[] args) {\n        printNumbers(1, 10);\n    }\n    \n    public static void printNumbers(int start, int end) {\n        for (int i = start; i <= end; i++) {\n            System.out.println(i);\n        }\n    }\n}\n```'}

# %%
# !pip install langchain_core
# Out:
# Requirement already satisfied: langchain_core in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langchain_core) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langchain_core) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langchain_core) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langchain_core) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langchain_core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langchain_core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langchain_core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.34.2)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: anyio in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (4.13.0)
# Requirement already satisfied: certifi in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.9)
# Requirement already satisfied: idna in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.16)
# Requirement already satisfied: h11>=0.16 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.7.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/seong-yumin/.local/share/virtualenvs/boaz_project2-ZZ_6wz1n/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.3.1)

# %%
from langchain_core.prompts import (
    PromptTemplate,
    MessagesPlaceholder,
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
    SystemMessagePromptTemplate,
    AIMessagePromptTemplate,
    FewShotChatMessagePromptTemplate,
    FewShotPromptWithTemplates
)
