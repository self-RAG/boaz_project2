# %%
# !pip install pipenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 8.6 MB/s  0:00:00m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 47.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pipenv]2m3/4 [pipenv]env]
# ...

# %%
OPENAI_API_KEY='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'

# %%
# !pip install langchain_community
# !pip install langchain_openai
# Out:
# ...
#   Using cached langchain_core-1.4.0-py3-none-any.whl.metadata (4.5 kB)
# ...
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached langsmith-0.8.5-py3-none-any.whl.metadata (15 kB)
# ...
# Using cached langchain_core-1.4.0-py3-none-any.whl (548 kB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Using cached langsmith-0.8.5-py3-none-any.whl (399 kB)
# ...
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.1.147
#     Uninstalling langsmith-0.1.147:
#       Successfully uninstalled langsmith-0.1.147
#   Attempting uninstall: langchain-core━━━━━━━━━━ 0/3 [langsmith]
#     Found existing installation: langchain-core 0.3.630/3 [langsmith]
#     Uninstalling langchain-core-0.3.63:━━━━━ 0/3 [langsmith]
#       Successfully uninstalled langchain-core-0.3.632m0/3 [langsmith]
#   Attempting uninstall: langchain-text-splitters━━━━━━━━━━━━━━━━━━ 1/3 [langchain-core]
# ...

# %%
# !pip install -U langchain langchain-core langchain-community langchain-openai
# Out:
# ...
#   Using cached langchain-1.3.1-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached langgraph-1.2.1-py3-none-any.whl.metadata (8.0 kB)
# ...
#   Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# ...
# Using cached langchain-1.3.1-py3-none-any.whl (114 kB)
# Using cached langgraph-1.2.1-py3-none-any.whl (235 kB)
# Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# ...
#   Attempting uninstall: langgraph-prebuilt
#     Found existing installation: langgraph-prebuilt 1.0.13
#     Uninstalling langgraph-prebuilt-1.0.13:
#       Successfully uninstalled langgraph-prebuilt-1.0.13
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.0.10
#     Uninstalling langgraph-1.0.10:
#       Successfully uninstalled langgraph-1.0.10
#   Attempting uninstall: langchain0m━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [langgraph]
#     Found existing installation: langchain 0.3.3━━━━━━━━━━━━━━ 1/3 [langgraph]
# ...

# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
OPENAI_API_KEY='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'
# api key 로딩
load_dotenv()

# open ai chat 생성
llm = ChatOpenAI()

# 질의 내용
question = "너이름이뭐야"

# 실행
result = llm.invoke(question)
print(result)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[2], line 8
#       5 load_dotenv()
#       7 # open ai chat 생성
# ----> 8 llm = ChatOpenAI()
#      10 # 질의 내용
#      11 question = "너이름이뭐야"
#
# File ~/opt/anaconda3/envs/yumin/lib/python3.10/site-packages/langchain_core/load/serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/opt/anaconda3/envs/yumin/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1265, in BaseChatOpenAI.validate_environment(self)
#    1251         self.http_async_client = _build_proxied_async_httpx_client(
#    1252             proxy=self.openai_proxy,
# ...
